# %% [markdown]
# # Part II - (201902 FORD-GO-BIKE DATASET)
# ## by Ighoruemuse, Omojevwe Rachael

# %% [markdown]
# ## Investigation Overview
#
# > In this investigation I want to look at the effects of trip characteristics on their duration; how it can be used to predict durations. The main focus were on age, user_type, and gender.
#
#
#
# ## Dataset Overview
#
# > The dataset consisted of 183412 entries rows in the dataset with 16 columns. The features included are: trip duration(in sec), start_time, end_time, station informations(start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_station_id, end_station_name, end_station_latitude and end_station_longitude), informations on members(bike_id, user_type, member_birth_year, member_gender, bike_share_for_all_trip).

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df_2 = pd.read_csv('clean_2019fordgobike.csv')
df_2.head()
# Out:
#                 start_time                 end_time  start_station_id  \
# 0  2019-02-28 23:54:18.549  2019-03-01 00:20:44.074               7.0
# 1  2019-02-28 23:49:58.632  2019-03-01 00:19:51.760              93.0
# 2  2019-02-28 23:55:35.104  2019-03-01 00:14:42.588             300.0
# 3  2019-02-28 23:41:06.766  2019-03-01 00:08:02.756              10.0
# 4  2019-02-28 23:41:48.790  2019-03-01 00:07:59.715              10.0
#
#              start_station_name  start_station_latitude  \
# 0           Frank H Ogawa Plaza               37.804562
# 1  4th St at Mission Bay Blvd S               37.770407
# 2          Palm St at Willow St               37.317298
# 3    Washington St at Kearny St               37.795393
# 4    Washington St at Kearny St               37.795393
#
#    start_station_longitude  end_station_id          end_station_name  \
# 0              -122.271738           222.0     10th Ave at E 15th St
# 1              -122.391198           323.0        Broadway at Kearny
# 2              -121.884995           312.0  San Jose Diridon Station
# 3              -122.404770           127.0    Valencia St at 21st St
# 4              -122.404770           127.0    Valencia St at 21st St
#
#    end_station_latitude  end_station_longitude     ...      member_birth_year  \
# 0             37.792714            -122.248780     ...                   1974
# 1             37.798014            -122.405950     ...                   1959
# 2             37.329732            -121.901782     ...                   1983
# 3             37.756708            -122.421025     ...                   1989
# 4             37.756708            -122.421025     ...                   1988
#
#   member_gender  bike_share_for_all_trip start_time_dayofweek  \
# 0          Male                     True                  Thu
# 1          Male                    False                  Thu
# 2        Female                    False                  Thu
# 3          Male                    False                  Thu
# 4         Other                    False                  Thu
#
#    start_time_month end_time_dayofweek end_time_month duration_min  \
# 0          February                Fri          March    26.416667
# 1          February                Fri          March    29.883333
# 2          February                Fri          March    19.116667
# 3          February                Fri          March    26.916667
# 4          February                Fri          March    26.166667
#
#   start_time_hour  member_age
# 0              23          45
# 1              23          60
# 2              23          36
# 3              23          30
# 4              23          31
#
# [5 rows x 22 columns]

# %% [markdown]
# ## (Visualization 1)
#
# > Distribution of duration by members' age

# %% [markdown]
# * What is the relationship between the trip duration and age?

# %%
plt.figure(figsize=[14.70, 8.27])
sns.regplot(data = df_2, x = 'member_age', y = 'duration_min');
plt.title('Trip Duration and Age')
plt.xlabel('Member_Age')
plt.ylabel('Duration_min')
plt.show()

# %% [markdown]
# ## (Visualization 2)
#
# > Distribution by members' gender

# %% [markdown]
# * What is the relationship between the trip duration and gender?

# %%
plt.figure(figsize=[14.70, 8.27], dpi = 100)

sns.boxplot(data = df_2, x = "member_gender", y = "duration_min")
plt.xlabel('Gender');
plt.ylabel('Trip Duration in Minutes')

plt.title("Distribution of trip duration by Gender")

plt.show()

# %% [markdown]
# ## (Visualization 3)
#
# > Distribution by user type

# %% [markdown]
# * What is the relationship between trip durations and user type?

# %%
# using a violin plot to show the relationship
plt.figure(figsize=[14.70, 8.27], dpi = 100)

sns.violinplot(data = df_2, x = "user_type", y = "duration_min")
plt.xlabel('User Type');
plt.ylabel('Trip Duration in Minutes')

plt.title("Distribution of trip duration by user type")

plt.show()

# %% [markdown]
# ## (Visualization 4)
#
# > Distribution by start time day of the week

# %% [markdown]
# * How do different days of the week affect the duration of the trips?

# %%
# using a barplot
plt.tight_layout()
plt.figure(figsize=[14.70, 8.27], dpi = 100)

base_color = sns.color_palette()[0]
sns.barplot(data = df_2, x = "start_time_dayofweek", y = "duration_min", color=base_color)
plt.xlabel('Day of Week');
plt.ylabel('Avg. Trip Duration in Minutes')

plt.show();

# %% [markdown]
# ## (Visualization 5)
# > Distribution by user type over hours of the day

# %% [markdown]
# * How do user types use the bike system at different hours of each day?

# %%
plt.figure(figsize=[14.70, 8.27], dpi = 100)

sns.countplot(data = df_2, x = "start_time_hour", hue='user_type')
plt.title("trip distribution over day hours - by user type")
plt.xlabel('Day Hours')
plt.ylabel('Count')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ### Generate Slideshow
# Once you're ready to generate your slideshow, use the `jupyter nbconvert` command to generate the HTML slide show.

# %%
# Use this command if you are running this file in local
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck_template.ipynb to slides
# [NbConvertApp] Writing 435838 bytes to Part_II_slide_deck_template.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.6/site-packages/jupyter_core/application.py", line 266, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.6/site-packages/nbconvert/nbconvertapp.py", line 337, in start
#     self.convert_notebooks()
#   File "/opt/conda/lib/python3.6/site-packages/nbconvert/nbconvertapp.py", line 507, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/opt/conda/lib/python3.6/site-packages/nbconvert/nbconvertapp.py", line 480, in convert_single_notebook
#     self.postprocess_single_notebook(write_results)
#   File "/opt/conda/lib/python3.6/site-packages/nbconvert/nbconvertapp.py", line 452, in postprocess_single_notebook
#     self.postprocessor(write_results)
#   File "/opt/conda/lib/python3.6/site-packages/nbconvert/postprocessors/base.py", line 28, in __call__
#     self.postprocess(input)
#   File "/opt/conda/lib/python3.6/site-packages/nbconvert/postprocessors/serve.py", line 95, in postprocess
#     http_server.listen(self.port, address=self.ip)
#   File "/opt/conda/lib/python3.6/site-packages/tornado/tcpserver.py", line 142, in listen
#     sockets = bind_sockets(port, address=address)
#   File "/opt/conda/lib/python3.6/site-packages/tornado/netutil.py", line 197, in bind_sockets
#     sock.bind(sockaddr)
# OSError: [Errno 98] Address already in use
